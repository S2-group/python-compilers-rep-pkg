# %%
# %load_ext autoreload
# %autoreload 2

# %%
import glob, os
import pandas as pd
import numpy as np
import seaborn as sns
from itertools import product
import matplotlib.pyplot as plt
import utils

# %%
from pathlib import Path
current_working_directory = Path.cwd()

# %%
METRIC = 'execution_time'
SERVER = 'gl2'

# %%
DATAPATH = f"../experiments/{SERVER}_data.csv"

# %%
data = pd.read_csv(DATAPATH)

# %%
data[METRIC] = data[METRIC] / 60

# %%
subjects = list(set(data['subject'].values))
targets = ['mandelbrot', 'fannkuch_redux', 'binary_trees', 'n_body', 'spectralnorm', 'k_nucleotide', 'fasta']

GROUPS = list(
    product(subjects, targets)
)

# %%
data['subject'] = pd.Categorical(
    data['subject'],
    ['cpython', 'pypy', 'numba', 'pyston-lite', 'py3.13-jit', 'nuitka', 'cython', 'codon', 'mypyc']
)

# %% [markdown]
# ## Descriptive Statistics

# %% [markdown]
# ### Descriptive Statistics per Benchmark

# %%
def reform(dictionary):
    return {(outerKey, innerKey): values for outerKey, innerDict in dictionary.items() for innerKey, values in innerDict.items()}

# %%
descriptive = []
for subject, target in GROUPS:
    df = utils.get_rows_by_subject_target(data, subject, target)
    stats =  {'subject': subject, 'target' : target} | df[METRIC].describe().to_dict()
    descriptive.append(
        stats
    )

table = pd.DataFrame(descriptive)
table = table.sort_values(by='subject')
table
# Out:
#         subject          target  count       mean       std        min  \
# 25        codon    spectralnorm   10.0   0.186468  0.000922   0.185692
# 23        codon    binary_trees   10.0   0.585124  0.002850   0.582179
# 22        codon  fannkuch_redux   10.0   1.744883  0.001597   1.742863
# 21        codon      mandelbrot   10.0   2.394422  0.006040   2.386877
# 26        codon    k_nucleotide   10.0   1.595588  0.016777   1.574057
# ..          ...             ...    ...        ...       ...        ...
# 29  pyston-lite  fannkuch_redux   10.0  71.903415  0.731997  71.113775
# 30  pyston-lite    binary_trees   10.0  31.845834  0.234051  31.465777
# 32  pyston-lite    spectralnorm   10.0  13.952932  0.120883  13.888765
# 34  pyston-lite           fasta   10.0   8.334919  0.213539   8.142628
# 31  pyston-lite          n_body   10.0  17.484795  0.874649  17.058086
#
#           25%        50%        75%        max
# 25   0.185835   0.186043   0.186864   0.188598
# 23   0.582934   0.584482   0.586291   0.591339
# 22   1.743149   1.745539   1.746261   1.746576
# 21   2.390428   2.393518   2.397635   2.404490
# 26   1.580865   1.596529   1.607973   1.623040
# ..        ...        ...        ...        ...
# 29  71.296871  71.707273  72.393898  73.133576
# 30  31.680825  31.833649  32.028445  32.168291
# 32  13.898924  13.908397  13.943306  14.288539
# 34   8.152695   8.254482   8.510473   8.691558
# 31  17.187997  17.205505  17.267660  19.964744
#
# [63 rows x 10 columns]

# %% [markdown]
# latex_table = table.round(3).to_latex(index=False, float_format="%.2f")
# print(latex_table)

# %% [markdown]
# ### Aggregated Descriptive Statistics

# %%
descriptive = []
for subject in subjects:
    df = data[data['subject'] == subject]
    stats = {'subject': subject} | df[METRIC].describe().to_dict()
    descriptive.append(stats)

table = pd.DataFrame(descriptive)
table = table.sort_values(by='subject')
table
# Out:
#        subject  count       mean        std       min       25%        50%  \
# 3        codon   70.0   1.039890   0.807955  0.185692  0.195549   0.584482
# 1      cpython   70.0  25.533828  20.623406  8.123457  8.675419  17.144353
# 2       cython   70.0  22.802496  14.715401  7.399139  8.801043  24.459806
# 5        mypyc   69.0  22.734720  19.823140  8.862955  9.375203  13.243384
# 8       nuitka   70.0  21.881853  14.952020  7.052594  7.350140  21.873589
# 6        numba   70.0   2.145817   1.277018  0.382412  0.952345   1.735417
# 0   py3.13-jit   70.0  20.232385  12.696134  8.880125  9.800006  15.636411
# 7         pypy   70.0   2.358685   1.388681  0.585438  0.886600   2.245310
# 4  pyston-lite   70.0  25.644125  20.763091  8.142628  8.693952  17.205505
#
#          75%        max
# 3   1.742961   2.404490
# 1  31.650762  72.173939
# 2  29.116473  51.952886
# 5  26.259597  84.997330
# 8  27.205338  52.562345
# 6   3.085244   4.517659
# 0  30.600745  61.799039
# 7   3.363681   4.769793
# 4  31.676652  73.133576

# %%
latex_table = table.round(3).to_latex(index=False, float_format="%.2f")
print(latex_table)
# Out:
# \begin{tabular}{lrrrrrrrr}
# \toprule
# subject & count & mean & std & min & 25% & 50% & 75% & max \\
# \midrule
# codon & 70.00 & 1.04 & 0.81 & 0.19 & 0.20 & 0.58 & 1.74 & 2.40 \\
# cpython & 70.00 & 25.53 & 20.62 & 8.12 & 8.68 & 17.14 & 31.65 & 72.17 \\
# cython & 70.00 & 22.80 & 14.71 & 7.40 & 8.80 & 24.46 & 29.12 & 51.95 \\
# mypyc & 69.00 & 22.73 & 19.82 & 8.86 & 9.38 & 13.24 & 26.26 & 85.00 \\
# nuitka & 70.00 & 21.88 & 14.95 & 7.05 & 7.35 & 21.87 & 27.20 & 52.56 \\
# numba & 70.00 & 2.15 & 1.28 & 0.38 & 0.95 & 1.74 & 3.08 & 4.52 \\
# py3.13-jit & 70.00 & 20.23 & 12.70 & 8.88 & 9.80 & 15.64 & 30.60 & 61.80 \\
# pypy & 70.00 & 2.36 & 1.39 & 0.58 & 0.89 & 2.25 & 3.36 & 4.77 \\
# pyston-lite & 70.00 & 25.64 & 20.76 & 8.14 & 8.69 & 17.21 & 31.68 & 73.13 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## BarPlots

# %%
colors = [
    "#FF6B6B",  # Coral Red
    "#4ECDC4",  # Turquoise
    "#FFA07A",  # Light Salmon
    "#6A3D9A",  # Purple
    "#FFD700",  # Gold
    "#45B7D1",  # Sky Blue
    "#98D8C8",  # Mint
    "#FF69B4",  # Hot Pink
    "#8B4513"   # Saddle Brown
]

# %%
plt.rcParams.update({'font.size': 12, 'font.family': 'serif'})
fig, axes = plt.subplots(1, 7, figsize=(26, 3))
axs_flat = axes.flatten()

for i in range(7):
    df = data[data['target'] == targets[i]]
    df.sort_values(by=['subject'])
    sns.barplot(
        x="target", y=METRIC, hue="subject", capsize = 0.5, errorbar=None, edgecolor = '0.1', lw=2, data=df, ax = axs_flat[i], dodge=True,
        palette=colors
    )

    axs_flat[i].get_legend().remove()
    axs_flat[i].set_xlabel('')
    axs_flat[i].set_ylabel('')
    axs_flat[i].tick_params(axis='x', labelsize=18)
    
    first_bar = axs_flat[i].patches[0]
    bar_height = first_bar.get_height()
    axs_flat[i].axhline(y=bar_height, color='red', linestyle='--', linewidth=2)
        
plt.subplots_adjust(wspace=0)
fig.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
fig.subplots_adjust(bottom=0.1, top=0.9, left=0.1, right=0.9, hspace=0.4, wspace=0.4)

plt.savefig(f"{SERVER}_{METRIC}.pdf", format="pdf", dpi=300, bbox_inches="tight", transparent=True)

plt.show()

# %% [markdown]
# ## Normality

# %%
utils.plot_qq_grid(data, METRIC)

# %% [markdown]
# ## Kruskal

# %% [markdown]
# from scipy.stats import kruskal

# %% [markdown]
# def calculate_kruskal(samples):
#     stat, p_value = kruskal(*samples)
#     return {'stat': stat, 'p_value': p_value}

# %% [markdown]
# utils.map_to_tasks(data, calculate_kruskal, METRIC)

# %% [markdown]
# ## Cliffs Delta

# %% [markdown]
# from cliffs_delta import cliffs_delta

# %% [markdown]
# pd.set_option('display.max_rows', 1000)

# %% [markdown]
# cliffs_res = utils.compare_quantization(data, cliffs_delta, METRIC)

# %% [markdown]
# ## Improvement and Delta
